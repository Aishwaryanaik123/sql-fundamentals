# %%
from IPython.display import Image, display

print("Data Visualization Report")

display(Image(filename="monthly_sales.png"))
display(Image(filename="monthly_profit.png"))
display(Image(filename="customers_vs_sales.png"))
display(Image(filename="sales_distribution.png"))
display(Image(filename="sales_boxplot.png"))
# Out:
# Data Visualization Report
